# %%
# colors=['#EFCB68', '#ED6A5E', "#7DCFB6", "#B191FF", "#0075A2"],

import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from concurrent.futures import ProcessPoolExecutor, as_completed

import sys
sys.path.append('/home/agustin/phd/synthesis')
sys.path.append('/home/agustin/phd/synthesis/tests/D3/evaluation')

import utils.functions as fc
import utils.nifti_functions as nfc
import utils.util_freesurfer_segmentation as ufs
import utils.data_normalization as data_normalization
import utils.statistics as ustats

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
from matplotlib.ticker import FixedLocator
# Mostrar todas las columnas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# %%
aa, affine = nfc.load_nifti("/home/agustin/phd/synthesis/data/MNI_template/usrl/mni_icbm152_t1synthsr_tal_nlin_sym_09a.nii.gz")
print(affine)
# Out:
# (array([[   1.,    0.,    0.,  -98.],
#        [   0.,    1.,    0., -134.],
#        [   0.,    0.,    1.,  -72.],
#        [   0.,    0.,    0.,    1.]]), <nibabel.nifti1.Nifti1Header object at 0x7fbe5caccd10>)
